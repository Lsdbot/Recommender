# %%
import pandas as pd

from sqlalchemy import create_engine

# %%
db = pd.read_parquet("/home/sergey/projects/Credit_scoring/raw/train_data/train_data_0.pq")

# %%
db2 = pd.read_parquet("/home/sergey/projects/Credit_scoring/raw/train_data/train_data_1.pq")

# %%
db
# Out:
#              id  rn  pre_since_opened  pre_since_confirmed  pre_pterm  \
# 0             0   1                18                    9          2
# 1             0   2                18                    9         14
# 2             0   3                18                    9          4
# 3             0   4                 4                    1          9
# 4             0   5                 5                   12         15
# ...         ...  ..               ...                  ...        ...
# 1974719  249998   4                 1                    9         14
# 1974720  249998   5                 7                    9          4
# 1974721  249999   1                 9                    0         10
# 1974722  249999   2                 9                   16         10
# 1974723  249999   3                 9                    9          6
#
#          pre_fterm  pre_till_pclose  pre_till_fclose  pre_loans_credit_limit  \
# ...
